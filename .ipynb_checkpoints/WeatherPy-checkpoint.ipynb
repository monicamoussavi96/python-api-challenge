# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 583

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
target_url = url + weather_api_key
target_url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=b1db93c67e7e95bae1fdca941dc2d097'

# %%
weather_response = requests.get(target_url)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4, sort_keys=True))
# Out:
# {
#     "city": {
#         "coord": {
#             "lat": 55.7522,
#             "lon": 37.6156
#         },
#         "country": "RU",
#         "id": 524901,
#         "name": "Moscow",
#         "sunrise": 1590541131,
#         "sunset": 1590602096,
#         "timezone": 10800
#     },
#     "cnt": 40,
#     "cod": "200",
#     "list": [
#         {
#             "clouds": {
#                 "all": 89
#             },
#             "dt": 1590602400,
#             "dt_txt": "2020-05-27 18:00:00",
#             "main": {
#                 "feels_like": 287.93,
#                 "grnd_level": 1006,
#                 "humidity": 61,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "temp": 289.41,
#                 "temp_kf": 0.83,
#                 "temp_max": 289.41,
#                 "temp_min": 288.58
#             },
#             "rain": {
#                 "3h": 0.46
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 235,
#                 "speed": 1.7
#             }
#         },
#         {
#             "clouds": {
#                 "all": 91
#             },
#             "dt": 1590613200,
#             "dt_txt": "2020-05-27 21:00:00",
#             "main": {
#                 "feels_like": 284.89,
#                 "grnd_level": 1006,
#                 "humidity": 67,
#                 "pressure": 1022,
#                 "sea_level": 1022,
#                 "temp": 287.43,
#                 "temp_kf": 0.77,
#                 "temp_max": 287.43,
#                 "temp_min": 286.66
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 208,
#                 "speed": 3.04
#             }
#         },
#         {
#             "clouds": {
#                 "all": 95
#             },
#             "dt": 1590624000,
#             "dt_txt": "2020-05-28 00:00:00",
#             "main": {
#                 "feels_like": 283.65,
#                 "grnd_level": 1007,
#                 "humidity": 73,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "temp": 285.8,
#                 "temp_kf": 0.3,
#                 "temp_max": 285.8,
#                 "temp_min": 285.5
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 231,
#                 "speed": 2.39
#             }
#         },
#         {
#             "clouds": {
#                 "all": 91
#             },
#             "dt": 1590634800,
#             "dt_txt": "2020-05-28 03:00:00",
#             "main": {
#                 "feels_like": 283.53,
#                 "grnd_level": 1006,
#                 "humidity": 74,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "temp": 285.44,
#                 "temp_kf": 0.04,
#                 "temp_max": 285.44,
#                 "temp_min": 285.4
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 213,
#                 "speed": 1.99
#             }
#         },
#         {
#             "clouds": {
#                 "all": 49
#             },
#             "dt": 1590645600,
#             "dt_txt": "2020-05-28 06:00:00",
#             "main": {
#                 "feels_like": 287.64,
#                 "grnd_level": 1007,
#                 "humidity": 58,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "temp": 289.65,
#                 "temp_kf": 0,
#                 "temp_max": 289.65,
#                 "temp_min": 289.65
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 206,
#                 "speed": 2.28
#             }
#         },
#         {
#             "clouds": {
#                 "all": 20
#             },
#             "dt": 1590656400,
#             "dt_txt": "2020-05-28 09:00:00",
#             "main": {
#                 "feels_like": 290.25,
#                 "grnd_level": 1007,
#                 "humidity": 40,
#                 "pressure": 1022,
#                 "sea_level": 1022,
#                 "temp": 293.3,
#                 "temp_kf": 0,
#                 "temp_max": 293.3,
#                 "temp_min": 293.3
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 176,
#                 "speed": 3.08
#             }
#         },
#         {
#             "clouds": {
#                 "all": 26
#             },
#             "dt": 1590667200,
#             "dt_txt": "2020-05-28 12:00:00",
#             "main": {
#                 "feels_like": 291.84,
#                 "grnd_level": 1006,
#                 "humidity": 39,
#                 "pressure": 1021,
#                 "sea_level": 1021,
#                 "temp": 294.66,
#                 "temp_kf": 0,
#                 "temp_max": 294.66,
#                 "temp_min": 294.66
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 175,
#                 "speed": 3.02
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590678000,
#             "dt_txt": "2020-05-28 15:00:00",
#             "main": {
#                 "feels_like": 290.36,
#                 "grnd_level": 1005,
#                 "humidity": 51,
#                 "pressure": 1021,
#                 "sea_level": 1021,
#                 "temp": 293.2,
#                 "temp_kf": 0,
#                 "temp_max": 293.2,
#                 "temp_min": 293.2
#             },
#             "rain": {
#                 "3h": 0.19
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 169,
#                 "speed": 3.97
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1590688800,
#             "dt_txt": "2020-05-28 18:00:00",
#             "main": {
#                 "feels_like": 288.62,
#                 "grnd_level": 1005,
#                 "humidity": 64,
#                 "pressure": 1021,
#                 "sea_level": 1021,
#                 "temp": 290.52,
#                 "temp_kf": 0,
#                 "temp_max": 290.52,
#                 "temp_min": 290.52
#             },
#             "rain": {
#                 "3h": 0.28
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 175,
#                 "speed": 2.97
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590699600,
#             "dt_txt": "2020-05-28 21:00:00",
#             "main": {
#                 "feels_like": 287.69,
#                 "grnd_level": 1005,
#                 "humidity": 71,
#                 "pressure": 1022,
#                 "sea_level": 1022,
#                 "temp": 289.26,
#                 "temp_kf": 0,
#                 "temp_max": 289.26,
#                 "temp_min": 289.26
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 162,
#                 "speed": 2.65
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590710400,
#             "dt_txt": "2020-05-29 00:00:00",
#             "main": {
#                 "feels_like": 287.07,
#                 "grnd_level": 1004,
#                 "humidity": 72,
#                 "pressure": 1020,
#                 "sea_level": 1020,
#                 "temp": 288.51,
#                 "temp_kf": 0,
#                 "temp_max": 288.51,
#                 "temp_min": 288.51
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 109,
#                 "speed": 2.26
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590721200,
#             "dt_txt": "2020-05-29 03:00:00",
#             "main": {
#                 "feels_like": 285.18,
#                 "grnd_level": 1003,
#                 "humidity": 74,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 287.85,
#                 "temp_kf": 0,
#                 "temp_max": 287.85,
#                 "temp_min": 287.85
#             },
#             "rain": {
#                 "3h": 0.38
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 99,
#                 "speed": 3.93
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590732000,
#             "dt_txt": "2020-05-29 06:00:00",
#             "main": {
#                 "feels_like": 285.45,
#                 "grnd_level": 1002,
#                 "humidity": 79,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 288,
#                 "temp_kf": 0,
#                 "temp_max": 288,
#                 "temp_min": 288
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 98,
#                 "speed": 4.21
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590742800,
#             "dt_txt": "2020-05-29 09:00:00",
#             "main": {
#                 "feels_like": 287.32,
#                 "grnd_level": 1002,
#                 "humidity": 90,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 288.39,
#                 "temp_kf": 0,
#                 "temp_max": 288.39,
#                 "temp_min": 288.39
#             },
#             "rain": {
#                 "3h": 5.79
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "moderate rain",
#                     "icon": "10d",
#                     "id": 501,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 99,
#                 "speed": 3.15
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590753600,
#             "dt_txt": "2020-05-29 12:00:00",
#             "main": {
#                 "feels_like": 287.7,
#                 "grnd_level": 1001,
#                 "humidity": 91,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 288.95,
#                 "temp_kf": 0,
#                 "temp_max": 288.95,
#                 "temp_min": 288.95
#             },
#             "rain": {
#                 "3h": 4.46
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "moderate rain",
#                     "icon": "10d",
#                     "id": 501,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 73,
#                 "speed": 3.75
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590764400,
#             "dt_txt": "2020-05-29 15:00:00",
#             "main": {
#                 "feels_like": 290.17,
#                 "grnd_level": 1000,
#                 "humidity": 88,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 290.52,
#                 "temp_kf": 0,
#                 "temp_max": 290.52,
#                 "temp_min": 290.52
#             },
#             "rain": {
#                 "3h": 2.57
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 45,
#                 "speed": 3
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590775200,
#             "dt_txt": "2020-05-29 18:00:00",
#             "main": {
#                 "feels_like": 288.63,
#                 "grnd_level": 1000,
#                 "humidity": 96,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 289.21,
#                 "temp_kf": 0,
#                 "temp_max": 289.21,
#                 "temp_min": 289.21
#             },
#             "rain": {
#                 "3h": 7.68
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "moderate rain",
#                     "icon": "10n",
#                     "id": 501,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 56,
#                 "speed": 3.36
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590786000,
#             "dt_txt": "2020-05-29 21:00:00",
#             "main": {
#                 "feels_like": 287.45,
#                 "grnd_level": 999,
#                 "humidity": 96,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 288.56,
#                 "temp_kf": 0,
#                 "temp_max": 288.56,
#                 "temp_min": 288.56
#             },
#             "rain": {
#                 "3h": 3.43
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "moderate rain",
#                     "icon": "10n",
#                     "id": 501,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 46,
#                 "speed": 3.78
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590796800,
#             "dt_txt": "2020-05-30 00:00:00",
#             "main": {
#                 "feels_like": 286.16,
#                 "grnd_level": 999,
#                 "humidity": 95,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 288.1,
#                 "temp_kf": 0,
#                 "temp_max": 288.1,
#                 "temp_min": 288.1
#             },
#             "rain": {
#                 "3h": 0.97
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 57,
#                 "speed": 4.65
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590807600,
#             "dt_txt": "2020-05-30 03:00:00",
#             "main": {
#                 "feels_like": 285.95,
#                 "grnd_level": 999,
#                 "humidity": 94,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 287.91,
#                 "temp_kf": 0,
#                 "temp_max": 287.91,
#                 "temp_min": 287.91
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 66,
#                 "speed": 4.51
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590818400,
#             "dt_txt": "2020-05-30 06:00:00",
#             "main": {
#                 "feels_like": 286.4,
#                 "grnd_level": 999,
#                 "humidity": 91,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 288.49,
#                 "temp_kf": 0,
#                 "temp_max": 288.49,
#                 "temp_min": 288.49
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 59,
#                 "speed": 4.73
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1590829200,
#             "dt_txt": "2020-05-30 09:00:00",
#             "main": {
#                 "feels_like": 288.71,
#                 "grnd_level": 999,
#                 "humidity": 80,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 291.1,
#                 "temp_kf": 0,
#                 "temp_max": 291.1,
#                 "temp_min": 291.1
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 57,
#                 "speed": 5.44
#             }
#         },
#         {
#             "clouds": {
#                 "all": 97
#             },
#             "dt": 1590840000,
#             "dt_txt": "2020-05-30 12:00:00",
#             "main": {
#                 "feels_like": 291.01,
#                 "grnd_level": 998,
#                 "humidity": 66,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 294.05,
#                 "temp_kf": 0,
#                 "temp_max": 294.05,
#                 "temp_min": 294.05
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 51,
#                 "speed": 6.3
#             }
#         },
#         {
#             "clouds": {
#                 "all": 64
#             },
#             "dt": 1590850800,
#             "dt_txt": "2020-05-30 15:00:00",
#             "main": {
#                 "feels_like": 289.61,
#                 "grnd_level": 997,
#                 "humidity": 70,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 293.12,
#                 "temp_kf": 0,
#                 "temp_max": 293.12,
#                 "temp_min": 293.12
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 43,
#                 "speed": 6.98
#             }
#         },
#         {
#             "clouds": {
#                 "all": 82
#             },
#             "dt": 1590861600,
#             "dt_txt": "2020-05-30 18:00:00",
#             "main": {
#                 "feels_like": 285.91,
#                 "grnd_level": 998,
#                 "humidity": 74,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 290.4,
#                 "temp_kf": 0,
#                 "temp_max": 290.4,
#                 "temp_min": 290.4
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 45,
#                 "speed": 7.55
#             }
#         },
#         {
#             "clouds": {
#                 "all": 98
#             },
#             "dt": 1590872400,
#             "dt_txt": "2020-05-30 21:00:00",
#             "main": {
#                 "feels_like": 283.45,
#                 "grnd_level": 997,
#                 "humidity": 63,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 288.69,
#                 "temp_kf": 0,
#                 "temp_max": 288.69,
#                 "temp_min": 288.69
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 51,
#                 "speed": 7.01
#             }
#         },
#         {
#             "clouds": {
#                 "all": 73
#             },
#             "dt": 1590883200,
#             "dt_txt": "2020-05-31 00:00:00",
#             "main": {
#                 "feels_like": 281.8,
#                 "grnd_level": 997,
#                 "humidity": 71,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 286.89,
#                 "temp_kf": 0,
#                 "temp_max": 286.89,
#                 "temp_min": 286.89
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 48,
#                 "speed": 6.81
#             }
#         },
#         {
#             "clouds": {
#                 "all": 4
#             },
#             "dt": 1590894000,
#             "dt_txt": "2020-05-31 03:00:00",
#             "main": {
#                 "feels_like": 281.05,
#                 "grnd_level": 997,
#                 "humidity": 62,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 286.86,
#                 "temp_kf": 0,
#                 "temp_max": 286.86,
#                 "temp_min": 286.86
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 48,
#                 "speed": 7.16
#             }
#         },
#         {
#             "clouds": {
#                 "all": 17
#             },
#             "dt": 1590904800,
#             "dt_txt": "2020-05-31 06:00:00",
#             "main": {
#                 "feels_like": 282.28,
#                 "grnd_level": 997,
#                 "humidity": 47,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 289.52,
#                 "temp_kf": 0,
#                 "temp_max": 289.52,
#                 "temp_min": 289.52
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 45,
#                 "speed": 8.75
#             }
#         },
#         {
#             "clouds": {
#                 "all": 14
#             },
#             "dt": 1590915600,
#             "dt_txt": "2020-05-31 09:00:00",
#             "main": {
#                 "feels_like": 284.16,
#                 "grnd_level": 998,
#                 "humidity": 38,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "temp": 291.66,
#                 "temp_kf": 0,
#                 "temp_max": 291.66,
#                 "temp_min": 291.66
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 41,
#                 "speed": 8.81
#             }
#         },
#         {
#             "clouds": {
#                 "all": 7
#             },
#             "dt": 1590926400,
#             "dt_txt": "2020-05-31 12:00:00",
#             "main": {
#                 "feels_like": 285,
#                 "grnd_level": 998,
#                 "humidity": 39,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "temp": 292.11,
#                 "temp_kf": 0,
#                 "temp_max": 292.11,
#                 "temp_min": 292.11
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 38,
#                 "speed": 8.47
#             }
#         },
#         {
#             "clouds": {
#                 "all": 25
#             },
#             "dt": 1590937200,
#             "dt_txt": "2020-05-31 15:00:00",
#             "main": {
#                 "feels_like": 283.15,
#                 "grnd_level": 999,
#                 "humidity": 48,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 289.81,
#                 "temp_kf": 0,
#                 "temp_max": 289.81,
#                 "temp_min": 289.81
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 33,
#                 "speed": 8.08
#             }
#         },
#         {
#             "clouds": {
#                 "all": 22
#             },
#             "dt": 1590948000,
#             "dt_txt": "2020-05-31 18:00:00",
#             "main": {
#                 "feels_like": 279.71,
#                 "grnd_level": 1001,
#                 "humidity": 54,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "temp": 286.11,
#                 "temp_kf": 0,
#                 "temp_max": 286.11,
#                 "temp_min": 286.11
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 32,
#                 "speed": 7.23
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1590958800,
#             "dt_txt": "2020-05-31 21:00:00",
#             "main": {
#                 "feels_like": 277.78,
#                 "grnd_level": 1001,
#                 "humidity": 55,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 283.97,
#                 "temp_kf": 0,
#                 "temp_max": 283.97,
#                 "temp_min": 283.97
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 31,
#                 "speed": 6.48
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1590969600,
#             "dt_txt": "2020-06-01 00:00:00",
#             "main": {
#                 "feels_like": 276.42,
#                 "grnd_level": 1002,
#                 "humidity": 61,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 281.9,
#                 "temp_kf": 0,
#                 "temp_max": 281.9,
#                 "temp_min": 281.9
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 28,
#                 "speed": 5.35
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1590980400,
#             "dt_txt": "2020-06-01 03:00:00",
#             "main": {
#                 "feels_like": 275.89,
#                 "grnd_level": 1002,
#                 "humidity": 61,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "temp": 281.23,
#                 "temp_kf": 0,
#                 "temp_max": 281.23,
#                 "temp_min": 281.23
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 20,
#                 "speed": 5.01
#             }
#         },
#         {
#             "clouds": {
#                 "all": 0
#             },
#             "dt": 1590991200,
#             "dt_txt": "2020-06-01 06:00:00",
#             "main": {
#                 "feels_like": 278.72,
#                 "grnd_level": 1002,
#                 "humidity": 48,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 284.5,
#                 "temp_kf": 0,
#                 "temp_max": 284.5,
#                 "temp_min": 284.5
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind": {
#                 "deg": 9,
#                 "speed": 5.58
#             }
#         },
#         {
#             "clouds": {
#                 "all": 56
#             },
#             "dt": 1591002000,
#             "dt_txt": "2020-06-01 09:00:00",
#             "main": {
#                 "feels_like": 281.53,
#                 "grnd_level": 1001,
#                 "humidity": 39,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "temp": 287.25,
#                 "temp_kf": 0,
#                 "temp_max": 287.25,
#                 "temp_min": 287.25
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 3,
#                 "speed": 5.41
#             }
#         },
#         {
#             "clouds": {
#                 "all": 66
#             },
#             "dt": 1591012800,
#             "dt_txt": "2020-06-01 12:00:00",
#             "main": {
#                 "feels_like": 283.53,
#                 "grnd_level": 1000,
#                 "humidity": 42,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "temp": 288.75,
#                 "temp_kf": 0,
#                 "temp_max": 288.75,
#                 "temp_min": 288.75
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind": {
#                 "deg": 358,
#                 "speed": 5.24
#             }
#         },
#         {
#             "clouds": {
#                 "all": 100
#             },
#             "dt": 1591023600,
#             "dt_txt": "2020-06-01 15:00:00",
#             "main": {
#                 "feels_like": 281.48,
#                 "grnd_level": 999,
#                 "humidity": 62,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "temp": 286.1,
#                 "temp_kf": 0,
#                 "temp_max": 286.1,
#                 "temp_min": 286.1
#             },
#             "rain": {
#                 "3h": 0.34
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind": {
#                 "deg": 348,
#                 "speed": 5.24
#             }
#         }
#     ],
#     "message": 0
# }

# %%
print(weather_json['city']['name'])
# Out:
# Moscow

# %%
##set up lists to hold reponse info
cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0

# Loop through the list of cities and perform a request for data on each
for city in cities:
    weather_response = requests.get(target_url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        cityname.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Processing record {count} of Set 1 | {city}")
    except:
        print("Record not found") 
        pass
        
print("END")
# Out:
# Processing record 1 of Set 1 | mehamn
# Processing record 2 of Set 1 | bulgan
# Processing record 3 of Set 1 | tasiilaq
# Processing record 4 of Set 1 | cape town
# Processing record 5 of Set 1 | avarua
# Processing record 6 of Set 1 | busselton
# Processing record 7 of Set 1 | albany
# Processing record 8 of Set 1 | rikitea
# Processing record 9 of Set 1 | san quintin
# Processing record 10 of Set 1 | pangnirtung
# Processing record 11 of Set 1 | takoradi
# Processing record 12 of Set 1 | georgetown
# Processing record 13 of Set 1 | puerto ayora
# Processing record 14 of Set 1 | roma
# Processing record 15 of Set 1 | buala
# Processing record 16 of Set 1 | embu
# Processing record 17 of Set 1 | kapaa
# Processing record 18 of Set 1 | athabasca
# Processing record 19 of Set 1 | ushuaia
# Record not found
# Processing record 20 of Set 1 | miri
# Processing record 21 of Set 1 | guane
# Processing record 22 of Set 1 | cabo san lucas
# Processing record 23 of Set 1 | iquitos
# Processing record 24 of Set 1 | kodiak
# Processing record 25 of Set 1 | lompoc
# Processing record 26 of Set 1 | khovu-aksy
# Processing record 27 of Set 1 | atuona
# Processing record 28 of Set 1 | lashio
# Processing record 29 of Set 1 | saint-philippe
# Record not found
# Processing record 30 of Set 1 | bykovo
# Processing record 31 of Set 1 | faanui
# Processing record 32 of Set 1 | tiksi
# Processing record 33 of Set 1 | praia
# Processing record 34 of Set 1 | ponta delgada
# Processing record 35 of Set 1 | torquay
# Processing record 36 of Set 1 | chapais
# Processing record 37 of Set 1 | montana
# Processing record 38 of Set 1 | mangochi
# Processing record 39 of Set 1 | hermanus
# Processing record 40 of Set 1 | petropavlovsk-kamchatskiy
# Processing record 41 of Set 1 | leningradskiy
# Processing record 42 of Set 1 | ridgecrest
# Processing record 43 of Set 1 | sawakin
# Processing record 44 of Set 1 | ostrovnoy
# Processing record 45 of Set 1 | caravelas
# Record not found
# Processing record 46 of Set 1 | mataura
# Processing record 47 of Set 1 | butaritari
# Processing record 48 of Set 1 | longyearbyen
# Processing record 49 of Set 1 | victoria
# Processing record 50 of Set 1 | mayna
# Processing record 51 of Set 1 | srednekolymsk
# Processing record 52 of Set 1 | saskylakh
# Processing record 53 of Set 1 | hilo
# Processing record 54 of Set 1 | marsh harbour
# Processing record 55 of Set 1 | ribeira grande
# Processing record 56 of Set 1 | lagoa
# Processing record 57 of Set 1 | souillac
# Processing record 58 of Set 1 | uaua
# Processing record 59 of Set 1 | tlacotepec
# Processing record 60 of Set 1 | coreau
# Processing record 61 of Set 1 | mar del plata
# Processing record 62 of Set 1 | parit buntar
# Processing record 63 of Set 1 | jamestown
# Processing record 64 of Set 1 | inuvik
# Processing record 65 of Set 1 | cherskiy
# Processing record 66 of Set 1 | kavieng
# Processing record 67 of Set 1 | hay river
# Processing record 68 of Set 1 | romitan
# Processing record 69 of Set 1 | port alfred
# Processing record 70 of Set 1 | codrington
# Processing record 71 of Set 1 | shenjiamen
# Processing record 72 of Set 1 | beringovskiy
# Processing record 73 of Set 1 | bredasdorp
# Processing record 74 of Set 1 | vanimo
# Processing record 75 of Set 1 | tuktoyaktuk
# Processing record 76 of Set 1 | nikolskoye
# Processing record 77 of Set 1 | robertsport
# Processing record 78 of Set 1 | talnakh
# Processing record 79 of Set 1 | arraial do cabo
# Record not found
# Processing record 80 of Set 1 | punta arenas
# Record not found
# Processing record 81 of Set 1 | carovigno
# Processing record 82 of Set 1 | jacksonville
# Processing record 83 of Set 1 | aklavik
# Processing record 84 of Set 1 | yellowknife
# Processing record 85 of Set 1 | inirida
# Processing record 86 of Set 1 | nelson bay
# Processing record 87 of Set 1 | hithadhoo
# Processing record 88 of Set 1 | dunedin
# Processing record 89 of Set 1 | narsaq
# Processing record 90 of Set 1 | pathein
# Processing record 91 of Set 1 | abha
# Processing record 92 of Set 1 | itarema
# Processing record 93 of Set 1 | orangeburg
# Processing record 94 of Set 1 | new norfolk
# Processing record 95 of Set 1 | namibe
# Record not found
# Processing record 96 of Set 1 | oranjemund
# Processing record 97 of Set 1 | magnor
# Processing record 98 of Set 1 | east london
# Processing record 99 of Set 1 | benidorm
# Record not found
# Processing record 100 of Set 1 | togur
# Processing record 101 of Set 1 | dikson
# Processing record 102 of Set 1 | lavrentiya
# Processing record 103 of Set 1 | birjand
# Processing record 104 of Set 1 | merauke
# Processing record 105 of Set 1 | norman wells
# Record not found
# Processing record 106 of Set 1 | san vicente de canete
# Processing record 107 of Set 1 | kapuskasing
# Processing record 108 of Set 1 | chuy
# Processing record 109 of Set 1 | zhanaozen
# Processing record 110 of Set 1 | longonjo
# Processing record 111 of Set 1 | cherbourg
# Processing record 112 of Set 1 | lagos
# Processing record 113 of Set 1 | port elizabeth
# Processing record 114 of Set 1 | vaini
# Processing record 115 of Set 1 | half moon bay
# Processing record 116 of Set 1 | henties bay
# Processing record 117 of Set 1 | bethel
# Processing record 118 of Set 1 | bluff
# Processing record 119 of Set 1 | marienburg
# Record not found
# Processing record 120 of Set 1 | tessalit
# Processing record 121 of Set 1 | vangaindrano
# Processing record 122 of Set 1 | diego de almagro
# Processing record 123 of Set 1 | broome
# Processing record 124 of Set 1 | basco
# Record not found
# Processing record 125 of Set 1 | santo domingo
# Processing record 126 of Set 1 | asau
# Processing record 127 of Set 1 | cangzhou
# Processing record 128 of Set 1 | marawi
# Processing record 129 of Set 1 | pishin
# Processing record 130 of Set 1 | usinsk
# Processing record 131 of Set 1 | vershino-darasunskiy
# Processing record 132 of Set 1 | chicama
# Processing record 133 of Set 1 | meulaboh
# Processing record 134 of Set 1 | port hardy
# Processing record 135 of Set 1 | kyakhta
# Processing record 136 of Set 1 | muana
# Processing record 137 of Set 1 | kaitangata
# Processing record 138 of Set 1 | ingleside
# Processing record 139 of Set 1 | severo-kurilsk
# Processing record 140 of Set 1 | udachnyy
# Processing record 141 of Set 1 | serenje
# Processing record 142 of Set 1 | barrow
# Processing record 143 of Set 1 | coihaique
# Processing record 144 of Set 1 | galle
# Processing record 145 of Set 1 | miracema
# Processing record 146 of Set 1 | nong phai
# Processing record 147 of Set 1 | lisakovsk
# Processing record 148 of Set 1 | yuty
# Processing record 149 of Set 1 | dudinka
# Record not found
# Processing record 150 of Set 1 | ngunguru
# Processing record 151 of Set 1 | yatou
# Processing record 152 of Set 1 | sobolevo
# Processing record 153 of Set 1 | chokurdakh
# Processing record 154 of Set 1 | tuatapere
# Processing record 155 of Set 1 | fairbanks
# Processing record 156 of Set 1 | labuhan
# Processing record 157 of Set 1 | ponta do sol
# Processing record 158 of Set 1 | havre-saint-pierre
# Processing record 159 of Set 1 | dingle
# Processing record 160 of Set 1 | nhulunbuy
# Processing record 161 of Set 1 | carnarvon
# Processing record 162 of Set 1 | thompson
# Record not found
# Processing record 163 of Set 1 | fort nelson
# Processing record 164 of Set 1 | shelburne
# Processing record 165 of Set 1 | saldanha
# Processing record 166 of Set 1 | luderitz
# Processing record 167 of Set 1 | umea
# Record not found
# Processing record 168 of Set 1 | vila velha
# Processing record 169 of Set 1 | touros
# Processing record 170 of Set 1 | guanica
# Processing record 171 of Set 1 | lebu
# Processing record 172 of Set 1 | moisei
# Processing record 173 of Set 1 | bandarbeyla
# Processing record 174 of Set 1 | fortuna
# Record not found
# Processing record 175 of Set 1 | portland
# Processing record 176 of Set 1 | qaanaaq
# Processing record 177 of Set 1 | airai
# Processing record 178 of Set 1 | namatanai
# Processing record 179 of Set 1 | sao joao da barra
# Processing record 180 of Set 1 | alofi
# Processing record 181 of Set 1 | pacific grove
# Record not found
# Processing record 182 of Set 1 | santa catarina de tepehuanes
# Processing record 183 of Set 1 | suntar
# Processing record 184 of Set 1 | gopalpur
# Processing record 185 of Set 1 | tautira
# Processing record 186 of Set 1 | burnie
# Processing record 187 of Set 1 | port moresby
# Processing record 188 of Set 1 | kununurra
# Processing record 189 of Set 1 | thinadhoo
# Processing record 190 of Set 1 | clinton
# Processing record 191 of Set 1 | semnan
# Processing record 192 of Set 1 | itarana
# Processing record 193 of Set 1 | sakaraha
# Processing record 194 of Set 1 | taoudenni
# Processing record 195 of Set 1 | upernavik
# Processing record 196 of Set 1 | victor harbor
# Processing record 197 of Set 1 | rodez
# Record not found
# Record not found
# Processing record 198 of Set 1 | tuy hoa
# Processing record 199 of Set 1 | mahebourg
# Processing record 200 of Set 1 | goderich
# Processing record 201 of Set 1 | necochea
# Processing record 202 of Set 1 | vao
# Processing record 203 of Set 1 | mount isa
# Processing record 204 of Set 1 | neyshabur
# Processing record 205 of Set 1 | bojnurd
# Processing record 206 of Set 1 | axim
# Processing record 207 of Set 1 | oskaloosa
# Processing record 208 of Set 1 | zhezkazgan
# Processing record 209 of Set 1 | betsiamites
# Processing record 210 of Set 1 | halifax
# Processing record 211 of Set 1 | kulhudhuffushi
# Processing record 212 of Set 1 | kieta
# Processing record 213 of Set 1 | abu kamal
# Processing record 214 of Set 1 | mnogovershinnyy
# Processing record 215 of Set 1 | sagua la grande
# Processing record 216 of Set 1 | north bend
# Processing record 217 of Set 1 | mount pleasant
# Record not found
# Processing record 218 of Set 1 | mahibadhoo
# Processing record 219 of Set 1 | twin falls
# Processing record 220 of Set 1 | tanggul
# Processing record 221 of Set 1 | bathsheba
# Processing record 222 of Set 1 | quatre cocos
# Record not found
# Processing record 223 of Set 1 | bilma
# Processing record 224 of Set 1 | kruisfontein
# Processing record 225 of Set 1 | deputatskiy
# Processing record 226 of Set 1 | adrar
# Processing record 227 of Set 1 | sergeyevka
# Processing record 228 of Set 1 | hobart
# Processing record 229 of Set 1 | cayenne
# Record not found
# Processing record 230 of Set 1 | torbay
# Record not found
# Processing record 231 of Set 1 | lata
# Processing record 232 of Set 1 | mulino
# Processing record 233 of Set 1 | bambous virieux
# Processing record 234 of Set 1 | innisfail
# Processing record 235 of Set 1 | rio gallegos
# Processing record 236 of Set 1 | gat
# Processing record 237 of Set 1 | sao filipe
# Processing record 238 of Set 1 | kenai
# Record not found
# Processing record 239 of Set 1 | el real de santa maria
# Processing record 240 of Set 1 | nacala
# Processing record 241 of Set 1 | wiwili
# Processing record 242 of Set 1 | kirakira
# Processing record 243 of Set 1 | malandag
# Processing record 244 of Set 1 | mao
# Processing record 245 of Set 1 | bengkulu
# Processing record 246 of Set 1 | maryborough
# Processing record 247 of Set 1 | liverpool
# Processing record 248 of Set 1 | euclides da cunha
# Processing record 249 of Set 1 | khatanga
# Record not found
# Processing record 250 of Set 1 | vila franca do campo
# Processing record 251 of Set 1 | xiaoweizhai
# Processing record 252 of Set 1 | aguilas
# Processing record 253 of Set 1 | itaituba
# Processing record 254 of Set 1 | luwuk
# Processing record 255 of Set 1 | katangli
# Processing record 256 of Set 1 | sitka
# Processing record 257 of Set 1 | kamina
# Processing record 258 of Set 1 | kalengwa
# Processing record 259 of Set 1 | santa ana
# Processing record 260 of Set 1 | sterling
# Processing record 261 of Set 1 | verkhnevilyuysk
# Processing record 262 of Set 1 | ratnagiri
# Processing record 263 of Set 1 | haileybury
# Processing record 264 of Set 1 | tezu
# Processing record 265 of Set 1 | flin flon
# Processing record 266 of Set 1 | san patricio
# Processing record 267 of Set 1 | cabedelo
# Processing record 268 of Set 1 | ambon
# Processing record 269 of Set 1 | hami
# Processing record 270 of Set 1 | huarmey
# Processing record 271 of Set 1 | cidreira
# Processing record 272 of Set 1 | ancud
# Processing record 273 of Set 1 | khudumelapye
# Processing record 274 of Set 1 | canutama
# Processing record 275 of Set 1 | hamilton
# Processing record 276 of Set 1 | chiang klang
# Processing record 277 of Set 1 | omboue
# Processing record 278 of Set 1 | iqaluit
# Processing record 279 of Set 1 | castro
# Processing record 280 of Set 1 | sur
# Processing record 281 of Set 1 | broken hill
# Processing record 282 of Set 1 | nyimba
# Processing record 283 of Set 1 | provideniya
# Processing record 284 of Set 1 | antalaha
# Processing record 285 of Set 1 | sawtell
# Processing record 286 of Set 1 | erenhot
# Processing record 287 of Set 1 | clyde river
# Processing record 288 of Set 1 | superior
# Processing record 289 of Set 1 | puerto carreno
# Processing record 290 of Set 1 | kloulklubed
# Processing record 291 of Set 1 | noumea
# Processing record 292 of Set 1 | hobyo
# Processing record 293 of Set 1 | esperance
# Processing record 294 of Set 1 | alice springs
# Processing record 295 of Set 1 | duluth
# Processing record 296 of Set 1 | dzilam gonzalez
# Processing record 297 of Set 1 | zhigansk
# Processing record 298 of Set 1 | cuxhaven
# Processing record 299 of Set 1 | conakry
# Processing record 300 of Set 1 | pundaguitan
# Processing record 301 of Set 1 | mirabad
# Processing record 302 of Set 1 | byron bay
# Processing record 303 of Set 1 | logansport
# Processing record 304 of Set 1 | kochkurovo
# Processing record 305 of Set 1 | benxi
# Processing record 306 of Set 1 | durango
# Record not found
# Processing record 307 of Set 1 | wilmington
# Processing record 308 of Set 1 | ryazan
# Record not found
# Processing record 309 of Set 1 | morros
# Processing record 310 of Set 1 | bunia
# Processing record 311 of Set 1 | inverell
# Processing record 312 of Set 1 | am timan
# Processing record 313 of Set 1 | blackwater
# Processing record 314 of Set 1 | eenhana
# Processing record 315 of Set 1 | pandan
# Processing record 316 of Set 1 | mecca
# Processing record 317 of Set 1 | guerrero negro
# Record not found
# Processing record 318 of Set 1 | palu
# Processing record 319 of Set 1 | grindavik
# Processing record 320 of Set 1 | seryshevo
# Processing record 321 of Set 1 | tahta
# Processing record 322 of Set 1 | bonavista
# Processing record 323 of Set 1 | getulio vargas
# Processing record 324 of Set 1 | along
# Processing record 325 of Set 1 | esso
# Processing record 326 of Set 1 | maun
# Processing record 327 of Set 1 | mogadishu
# Processing record 328 of Set 1 | dhidhdhoo
# Processing record 329 of Set 1 | puerto leguizamo
# Processing record 330 of Set 1 | basi
# Processing record 331 of Set 1 | te anau
# Processing record 332 of Set 1 | harindanga
# Processing record 333 of Set 1 | jining
# Processing record 334 of Set 1 | dakar
# Processing record 335 of Set 1 | mackenzie
# Record not found
# Record not found
# Processing record 336 of Set 1 | kikwit
# Processing record 337 of Set 1 | charters towers
# Processing record 338 of Set 1 | west odessa
# Processing record 339 of Set 1 | saint anthony
# Processing record 340 of Set 1 | kendari
# Processing record 341 of Set 1 | malvern
# Processing record 342 of Set 1 | tangi
# Record not found
# Processing record 343 of Set 1 | camacha
# Processing record 344 of Set 1 | coquimbo
# Processing record 345 of Set 1 | kincardine
# Processing record 346 of Set 1 | merritt island
# Processing record 347 of Set 1 | dingzhou
# Processing record 348 of Set 1 | colonia
# Processing record 349 of Set 1 | cap malheureux
# Processing record 350 of Set 1 | samarai
# Processing record 351 of Set 1 | lithakia
# Processing record 352 of Set 1 | hasaki
# Processing record 353 of Set 1 | panna
# Processing record 354 of Set 1 | mapiripan
# Processing record 355 of Set 1 | amazar
# Processing record 356 of Set 1 | komatipoort
# Processing record 357 of Set 1 | aksarka
# Processing record 358 of Set 1 | toma
# Processing record 359 of Set 1 | prieska
# Processing record 360 of Set 1 | tobol
# Processing record 361 of Set 1 | trat
# Processing record 362 of Set 1 | yenagoa
# Processing record 363 of Set 1 | buchanan
# Processing record 364 of Set 1 | pangody
# Processing record 365 of Set 1 | sabha
# Processing record 366 of Set 1 | inhambane
# Processing record 367 of Set 1 | biggar
# Processing record 368 of Set 1 | mbeya
# Processing record 369 of Set 1 | tambilil
# Processing record 370 of Set 1 | lac du bonnet
# Processing record 371 of Set 1 | laguna
# Processing record 372 of Set 1 | port keats
# Processing record 373 of Set 1 | ewa beach
# Processing record 374 of Set 1 | takhtamygda
# Record not found
# Processing record 375 of Set 1 | olavarria
# Processing record 376 of Set 1 | avera
# Processing record 377 of Set 1 | nabire
# Processing record 378 of Set 1 | tigil
# Processing record 379 of Set 1 | juba
# Record not found
# Processing record 380 of Set 1 | chihuahua
# Processing record 381 of Set 1 | roald
# Processing record 382 of Set 1 | socorro
# Processing record 383 of Set 1 | tocopilla
# Processing record 384 of Set 1 | ryotsu
# Processing record 385 of Set 1 | dongsheng
# Record not found
# Processing record 386 of Set 1 | waipawa
# Record not found
# Processing record 387 of Set 1 | atar
# Processing record 388 of Set 1 | jieshi
# Processing record 389 of Set 1 | high prairie
# Processing record 390 of Set 1 | biak
# Processing record 391 of Set 1 | dwarka
# Processing record 392 of Set 1 | lalin
# Processing record 393 of Set 1 | carauari
# Processing record 394 of Set 1 | klaksvik
# Processing record 395 of Set 1 | benghazi
# Processing record 396 of Set 1 | ahipara
# Processing record 397 of Set 1 | andenes
# Processing record 398 of Set 1 | wasilla
# Processing record 399 of Set 1 | nanortalik
# Processing record 400 of Set 1 | tukums
# Processing record 401 of Set 1 | andra
# Processing record 402 of Set 1 | bosaso
# Processing record 403 of Set 1 | harsin
# Processing record 404 of Set 1 | padang
# Processing record 405 of Set 1 | pevek
# Processing record 406 of Set 1 | sao francisco
# Processing record 407 of Set 1 | iisalmi
# Processing record 408 of Set 1 | hamza
# Processing record 409 of Set 1 | puerto ayacucho
# Processing record 410 of Set 1 | borazjan
# Record not found
# Processing record 411 of Set 1 | pedro ii
# Processing record 412 of Set 1 | adolfo lopez mateos
# Record not found
# Processing record 413 of Set 1 | sfantu gheorghe
# Processing record 414 of Set 1 | cavan
# Processing record 415 of Set 1 | peniche
# Processing record 416 of Set 1 | yoichi
# Processing record 417 of Set 1 | pringsewu
# Processing record 418 of Set 1 | lahaina
# Processing record 419 of Set 1 | itabira
# Record not found
# Processing record 420 of Set 1 | mana
# Processing record 421 of Set 1 | karratha
# Processing record 422 of Set 1 | umm lajj
# Processing record 423 of Set 1 | saint george
# Processing record 424 of Set 1 | aranos
# Processing record 425 of Set 1 | novaya ladoga
# Processing record 426 of Set 1 | marystown
# Processing record 427 of Set 1 | katsuura
# Record not found
# Processing record 428 of Set 1 | rawson
# Processing record 429 of Set 1 | fort saint james
# Processing record 430 of Set 1 | beloha
# Processing record 431 of Set 1 | kahului
# Processing record 432 of Set 1 | kaifeng
# Processing record 433 of Set 1 | petrovsk-zabaykalskiy
# Record not found
# Processing record 434 of Set 1 | mahajanga
# Processing record 435 of Set 1 | arman
# Processing record 436 of Set 1 | bairiki
# Processing record 437 of Set 1 | bachaquero
# Processing record 438 of Set 1 | havoysund
# Processing record 439 of Set 1 | kingston
# Processing record 440 of Set 1 | amapa
# Processing record 441 of Set 1 | brokopondo
# Processing record 442 of Set 1 | sirjan
# Processing record 443 of Set 1 | araouane
# Processing record 444 of Set 1 | iskateley
# Processing record 445 of Set 1 | san gabriel
# Processing record 446 of Set 1 | comodoro rivadavia
# Processing record 447 of Set 1 | rocha
# Record not found
# Processing record 448 of Set 1 | senanga
# Processing record 449 of Set 1 | poso
# Processing record 450 of Set 1 | mangrol
# Processing record 451 of Set 1 | muros
# Processing record 452 of Set 1 | boden
# Record not found
# Processing record 453 of Set 1 | korla
# Processing record 454 of Set 1 | poum
# Record not found
# Processing record 455 of Set 1 | ilulissat
# Processing record 456 of Set 1 | lazaro cardenas
# Processing record 457 of Set 1 | sorata
# Processing record 458 of Set 1 | brae
# Processing record 459 of Set 1 | saint-joseph
# Processing record 460 of Set 1 | vorobyevka
# Processing record 461 of Set 1 | eyl
# Processing record 462 of Set 1 | matara
# Processing record 463 of Set 1 | carman
# Processing record 464 of Set 1 | lasa
# Processing record 465 of Set 1 | mende
# Processing record 466 of Set 1 | garowe
# Processing record 467 of Set 1 | chany
# Processing record 468 of Set 1 | sault sainte marie
# Processing record 469 of Set 1 | petatlan
# Processing record 470 of Set 1 | kwekwe
# Processing record 471 of Set 1 | disna
# Processing record 472 of Set 1 | west chicago
# Processing record 473 of Set 1 | dhrangadhra
# Processing record 474 of Set 1 | sines
# Processing record 475 of Set 1 | saint charles
# Processing record 476 of Set 1 | bubaque
# Processing record 477 of Set 1 | nemuro
# Processing record 478 of Set 1 | melchor de mencos
# Processing record 479 of Set 1 | cockburn town
# Processing record 480 of Set 1 | baghpat
# Processing record 481 of Set 1 | lefka
# Processing record 482 of Set 1 | maceio
# Processing record 483 of Set 1 | port blair
# Processing record 484 of Set 1 | port macquarie
# Processing record 485 of Set 1 | anshun
# Processing record 486 of Set 1 | olga
# Processing record 487 of Set 1 | mount gambier
# Processing record 488 of Set 1 | aden
# Record not found
# Processing record 489 of Set 1 | manado
# Processing record 490 of Set 1 | ixtapa
# Record not found
# Processing record 491 of Set 1 | vatra dornei
# Processing record 492 of Set 1 | weihai
# Record not found
# Processing record 493 of Set 1 | tsivilsk
# Processing record 494 of Set 1 | agadez
# Processing record 495 of Set 1 | richards bay
# Processing record 496 of Set 1 | mayumba
# Processing record 497 of Set 1 | hopkinsville
# Processing record 498 of Set 1 | akyab
# Processing record 499 of Set 1 | omoa
# Processing record 500 of Set 1 | novobiryusinskiy
# Processing record 501 of Set 1 | port antonio
# Processing record 502 of Set 1 | matagami
# Processing record 503 of Set 1 | bouca
# Record not found
# Processing record 504 of Set 1 | ouesso
# Processing record 505 of Set 1 | tikamgarh
# Processing record 506 of Set 1 | ishigaki
# Processing record 507 of Set 1 | carutapera
# Processing record 508 of Set 1 | salalah
# Processing record 509 of Set 1 | lincoln
# Processing record 510 of Set 1 | inta
# Processing record 511 of Set 1 | aksu
# Processing record 512 of Set 1 | svetlogorsk
# Processing record 513 of Set 1 | ayni
# Processing record 514 of Set 1 | kayerkan
# Processing record 515 of Set 1 | linxia
# Processing record 516 of Set 1 | nuuk
# Processing record 517 of Set 1 | salinas
# Processing record 518 of Set 1 | hun
# Processing record 519 of Set 1 | george town
# Record not found
# Processing record 520 of Set 1 | constitucion
# Processing record 521 of Set 1 | marquette
# Processing record 522 of Set 1 | nivala
# Record not found
# Processing record 523 of Set 1 | hualmay
# Processing record 524 of Set 1 | la ronge
# Processing record 525 of Set 1 | numan
# Processing record 526 of Set 1 | hatillo
# Processing record 527 of Set 1 | ubrique
# Processing record 528 of Set 1 | ludvika
# Processing record 529 of Set 1 | isangel
# Processing record 530 of Set 1 | maragogi
# Record not found
# Processing record 531 of Set 1 | loralai
# Processing record 532 of Set 1 | mangaldai
# Processing record 533 of Set 1 | mehran
# Processing record 534 of Set 1 | sao felix do xingu
# Processing record 535 of Set 1 | saryozek
# END

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {"City": cityname,"Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
                "Wind Speed":wind_speed,"Country":country, "Date":date}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#         City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Mehamn   71.0357    27.8492     47.10        77          84        6.60
# 1     Bulgan   48.8125   103.5347     49.95        84         100       11.39
# 2   Tasiilaq   65.6145   -37.6368     38.89        71          66        3.44
# 3  Cape Town  -33.9258    18.4232     58.48        70          83       16.58
# 4     Avarua  -21.2078  -159.7750     74.68        77          17        6.73
#
#   Country        Date
# 0      NO  1590602400
# 1      MN  1590602400
# 2      GL  1590602400
# 3      ZA  1590602400
# 4      CK  1590602400

# %%
# Export the City_Data into a csv
weather_data.to_csv(r'output_data\my_weather_data.csv')
# Show Record Count
record_count = len(weather_data)
record_count
# Out:
# 535

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
scatlat = weather_data["Latitude"]
scattemp = weather_data["Max Temp"]

plt.scatter(scatlat,scattemp)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('scatplotlatitudemaxtemp')
plt.show()

#This code is analyzing the correlation between a cities latitude and its max temperature.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
scatlat = weather_data["Latitude"]
scathum = weather_data["Humidity"]

plt.scatter(scatlat,scathum)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('scatplotlatitudehumidity')
plt.show()
#This code is analyzing the correlation between a cities latitude and its percentage of humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
scatlat = weather_data["Latitude"]
scatcloud = weather_data["Cloudiness"]

plt.scatter(scatlat,scatcloud)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('scatplotlatitudecloudiness')
plt.show()
#This code is analyzing the correlation between a cities latitude and its percentage of cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
scatlat = weather_data["Latitude"]
scatwindsp = weather_data["Wind Speed"]

plt.scatter(scatlat,scatwindsp)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('scatplotlatitudewindspeed')
plt.show()
#This code is analyzing the correlation between a cities latitude and its wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = weather_data.loc[weather_data["Latitude"] >= 0,:]
southlat_df = weather_data.loc[weather_data["Latitude"] < 0,:]

northlat_df.head()
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0       Mehamn   71.0357    27.8492     47.10        77          84
# 1       Bulgan   48.8125   103.5347     49.95        84         100
# 2     Tasiilaq   65.6145   -37.6368     38.89        71          66
# 6       Albany   42.6001   -73.9662     83.19        55          18
# 8  San Quintín   30.4833  -115.9500     73.29        64           0
#
#    Wind Speed Country        Date
# 0        6.60      NO  1590602400
# 1       11.39      MN  1590602400
# 2        3.44      GL  1590602400
# 6        9.17      US  1590602400
# 8       11.32      MX  1590602400

# %%
southlat_df = weather_data.loc[weather_data["Latitude"] < 0,:]
southlat_df.head()
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 3      Cape Town  -33.9258    18.4232     58.48        70          83
# 4         Avarua  -21.2078  -159.7750     74.68        77          17
# 5      Busselton  -33.6500   115.3333     60.24        81          11
# 7        Rikitea  -23.1203  -134.9692     75.76        82           0
# 12  Puerto Ayora   -0.7393   -90.3518     76.87        75          67
#
#     Wind Speed Country        Date
# 3        16.58      ZA  1590602400
# 4         6.73      CK  1590602400
# 5        11.12      AU  1590602400
# 7        10.11      PF  1590602400
# 12       10.31      EC  1590602400

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('northerntemplat')
# Out:
# The r-squared is: -0.7956948968770605

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Max Temp"]
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('southerntemplat')
#The high r value indicates a strong positive correlation between latitude and max temperature.
# Out:
# The r-squared is: 0.8806839251318156

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('northernhumlat')
# Out:
# The r-squared is: 0.09584566903669309

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('southernhumlat')
#The low r values indicate a weak to no relationship between humidity and latitude.
# Out:
# The r-squared is: 0.0008161137056139045

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))
plt.savefig('northerncloudlat')
# Out:
# The r-squared is: 0.06713274871984558

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('southerncloudlat')

#The low r values indicate a weak positive relationship between latitude and cloudiness.
# Out:
# The r-squared is: 0.1698568500887021

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('northernwindlat')
# Out:
# The r-squared is: 0.0016072683963088512

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('southernwindlat')
# Out:
# The r-squared is: -0.2284190842127959

# %%
#The low r values indicate that there is no real relationship between wind speed and latitude. 
#The difference between the hemispheres doesn't seem to be significant enough to comment upon.
